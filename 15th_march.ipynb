# %% [raw]
# Q1  Explain the following with an example
# 1) Artificial Intelligence
# 2) Machine Learning
# 3) Deep Learning
#
# -> 1. Artificial Intelligence :- it is an area of computer science where the machine's get an
# ability to think like human and make decision. eg : recomendation system
# 2. Machine learning :- it a subset of artificial intellgence and it consist of statistical model
# which a machine can use by which it can make decision eg :- self driven car
# 3. Deep learning :- it is a subset of machine learning becuase of Deep learning the machine get
# the intelligence like human where it can not only make decision but also learn new things
# eg : chat bot like chat gpt
#
# Q2- What is supervised learning? List some examples of supervised learning.
#
# -> In supervised learning the outputs of a model are predecided for example :-  movie
# recomendation system
#
#
# Q3- What is unsupervised learning? List some examples of unsupervised learning.
#
# -> In unsupervised learning the outputs of the model are not predecided for example chat gpt
#
# Q4- What is the difference between AI, ML, DL, and DS?
#
# -> AI is the unversal set which contains ML and DL , DL is a subset of ML and DS has majority
# of AI but in that we also need knowledge of domain in which we are working .
# 1. Artificial Intelligence :- it is an area of computer science where the machine's get an
# ability to think like human and make decision. eg : recomendation system
# 2. Machine learning :- it a subset of artificial intellgence and it consist of statistical model
# which a machine can use by which it can make decision eg :- self driven car
# 3. Deep learning :- it is a subset of machine learning becuase of Deep learning the machine get
# the intelligence like human where it can not only make decision but also learn new things
# eg : chat bot like chat gpt
# Data Science : it includes some part from ml , dl and ai and it also required the knowledge of
# domain in which we are working. it used to draw meaningful insights from data , for example
# in recomendation system we collect the data from the user and recomend him the movies accordignly
#
# Q5- What are the main differences between supervised, unsupervised, and semi-supervised learning?
#
# -> in supervised the outputs of the models are fixed and the model is trained to predict that outputs
# in unsupervised learning the output of the model is not fixed and model is trained to generate the output
# in semi-supervised learning we have the combination of both the supervised and unsupervised learning
#
# Q6- What is train, test and validation split? Explain the importance of each term.
#
# -> train and test are the phases of the model where it is created and tested , the dataset use for this phase ,
# is different from the dataset used for validation phase , validation phase is a phase where the
# model is validated . model only has access to the train and test dataset , but it does not have
# access to the validaton dataset
#
# Q7- How can unsupervised learning be used in anomaly detection?
#
# -> consider the example where the material and method to manufacture tyre is given as an input
# to a unsupervised learning model , and it is train with a dataset that contains all the permutation
# of the method and material and their output , than under this situation unsupervised learning can be used to
# predict whether the tyre made from a particular method and material will be good or will it have
# an anomally
#
# Q8- List down some commonly used supervised learning algorithms and unsupervised learning
# algorithms.
#
# -> supervised learning :- linear regression ,decision trees
# unsupervised learning :- singular value decomposition and k mean
