# %%
import pandas as pd
import numpy as np

# Q1. Write a code to print the data present in the second row of the dataframe, df.
def print_second_row(df):
    print("Second row:", df.iloc[1])

# Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?
# loc uses labels, while iloc uses integer indexes.

# Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df
# then find the output for both new_df.loc[2] and new_df.iloc[2].
def reindex_and_access():
    data = {'column_1': [1, 2, 3, 4], 'column_2': [5, 6, 7, 8]}
    df = pd.DataFrame(data)
    reindex = [3, 0, 1, 2]
    new_df = df.reindex(reindex)
    print("new_df.loc[2]:", new_df.loc[2])
    print("new_df.iloc[2]:", new_df.iloc[2])

# Q4. Write a code to find the following statistical measurements for the above dataframe df1:
# (i) mean of each and every column present in the dataframe.
# (ii) standard deviation of column, ‘column_2’
def calculate_statistics(df):
    print("Mean of each column:")
    print(df.mean())
    print("Standard deviation of column_2:", df['column_2'].std())

# Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the
# mean of column, column_2.
# If you are getting errors in executing it then explain why.
def replace_data_and_calculate_mean(df):
    df.loc[2, 'column_2'] = "String"
    try:
        mean = df['column_2'].mean()
        print("Mean:", mean)
    except TypeError:
        print("Error: Cannot calculate mean of a column containing non-numeric values.")

# Q6. What do you understand about the windows function in pandas and list the types of windows
# functions?
# Window functions in pandas allow you to perform calculations over a sliding window of data.
# Types of window functions include rolling, expanding, and exponentially weighted.

# Q7. Write a code to print only the current month and year at the time of answering this question.
def print_current_month_year():
    import pandas as pd
    current_date = pd.Timestamp.today()
    print("Current month and year:", current_date.strftime("%B %Y"))

# Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and
# calculates the difference between them in days, hours, and minutes using Pandas time delta.
def calculate_time_difference():
    date1 = input("Enter the first date (YYYY-MM-DD): ")
    date2 = input("Enter the second date (YYYY-MM-DD): ")
    date1 = pd.to_datetime(date1)
    date2 = pd.to_datetime(date2)
    time_difference = date2 - date1
    print("Difference:", time_difference.days, "days", time_difference.seconds // 3600, "hours", time_difference.seconds % 3600 // 60, "minutes")

# Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified
# column to a categorical data type. The program should prompt the user to enter the file path, column
# name, and category order, and then display the sorted data.
def convert_to_categorical(file_path, column_name, category_order):
    df = pd.read_csv(file_path)
    df[column_name] = df[column_name].astype('category', categories=category_order, ordered=True)
    df = df.sort_values(by=column_name)
    print(df)

# Q10. Write a Python program that reads a CSV file containing sales data for different products and
# visualizes the data using a stacked bar chart to show the sales of each product category over time. The
# program should prompt the user to enter the file path and display the chart.
def visualize_sales_data(file_path):
    df = pd.read_csv(file_path)
    df.plot(kind='bar', stacked=True)
    plt.show()

# Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write
# a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and
# displays the results in a table.

def analyze_student_data(file_path):
    df = pd.read_csv(file_path)
    mean_score = df['Test Score'].mean()
    median_score = df['Test Score'].median()
    mode_score = df['Test Score'].mode()
    print("+-----------+--------+")
    print("| Statistic | Value |")
    print("+-----------+--------+")
    print("| Mean | {:.2f} |".format(mean_score))
    print("| Median | {} |".format(median_score))
    # Handle multiple modes:
    if mode_score.size > 1:
        mode_str = ", ".join(mode_score.astype(str))
    else:
        mode_str = str(mode_score.iloc[0])
    print("| Mode | {} |".format(mode_str))
    print("+-----------+--------+")

# Example usage:
if __name__ == "__main__":
    file_path = "student_data.csv"  # Replace with your actual file path
    analyze_student_data(file_path)
# Out:
# +-----------+--------+
# | Statistic | Value |
# +-----------+--------+
# | Mean | 83.50 |
# | Median | 85.0 |
# | Mode | 85 |
# +-----------+--------+
