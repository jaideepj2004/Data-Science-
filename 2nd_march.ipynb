# %%
import matplotlib.pyplot as plt
import numpy as np

# Q1. What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.
# Matplotlib is a powerful Python library for creating static, animated, and interactive visualizations.
# It is used for data visualization, exploratory data analysis, and scientific computing.
# Five plots that can be plotted using Pyplot:
# 1. Line plots
# 2. Scatter plots
# 3. Histograms
# 4. Bar charts
# 5. Pie charts

# Q2. What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# A scatter plot is a type of graph used to visualize the relationship between two numerical variables.

# Generate data
x = np.random.rand(100)  # Random x-values between 0 and 1
y = x + np.random.randn(100)  # Random y-values with some noise

# Create the scatter plot
plt.figure(figsize=(8, 6))  # Set figure size for readability
plt.scatter(x, y, color='blue', alpha=0.7, s=50)  # Configure markers
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot Example')
plt.grid(True)  # Add grid lines for better visualization
plt.tight_layout()  # Adjust spacing to prevent overlapping elements

plt.show()

# Q3. Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# The subplot() function is used to create multiple subplots within a single figure, allowing for the comparison of different datasets or visualizations within a single plot.

# Create the four line plots
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot
plt.plot(x1, y1, label='Line 1')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot
plt.plot(x2, y2, label='Line 2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)  # 2 rows, 2 columns, 3rd subplot
plt.plot(x3, y3, label='Line 3')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)  # 2 rows, 2 columns, 4th subplot
plt.plot(x4, y4, label='Line 4')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot 4')

plt.tight_layout()  # Adjust spacing to prevent overlapping
plt.show()

# Q4. What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# A bar plot is a type of chart used to represent categorical data or comparisons between groups.

# Data for bar plots
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Create the bar plot
plt.figure(figsize=(8, 6))
plt.bar(company, profit, color='blue')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.title('Bar Plot')
plt.show()

# Create the horizontal bar plot
plt.figure(figsize=(8, 6))
plt.barh(company, profit, color='orange')
plt.xlabel('Profit')
plt.ylabel('Company')
plt.title('Horizontal Bar Plot')
plt.show()

# Q5. What is a box plot? Why is it used? Using the following data plot a box plot.

# A box plot (also known as a box and whisker plot) is a graphical representation of the distribution of a dataset.
# It shows the median, quartiles, and potential outliers.

# Data for box plots
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Create the box plot
plt.figure(figsize=(8, 6))
plt.boxplot([box1, box2])
plt.xlabel('Box Plot')
plt.ylabel('Value')
plt.xticks([1, 2], ['Box 1', 'Box 2'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 47
#      44 plt.figure(figsize=(12, 8))
#      46 plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot
# ---> 47 plt.plot(x1, y1, label='Line 1')
#      48 plt.xlabel('X-axis')
#      49 plt.ylabel('Y-axis')
#
# NameError: name 'x1' is not defined
